# %% [markdown]
# ## PROBA.QA.1
#
# Let $ {\mathbf x} $   and $ {\mathbf  y} $  two discrete independent  r.v.s
# such that
#
# $ P_{{\mathbf x}}(-1)=0.1, P_{{\mathbf x}}(0)=0.8,   P_{{\mathbf x}}(1)=0.1 $
# and
# $ P_{{\mathbf y}}(1)=0.1, P_{{\mathbf y}}(2)=0.8,   P_{{\mathbf y}}(3)=0.1 $
#
# Compute
# $ E[{\mathbf x}], E[{\mathbf y }] $.
#
#
# If $ {\mathbf z}={\mathbf x}+{\mathbf  y} $ compute numerically
# $ E[{\mathbf z }]$ and verify
#  that  $ E[{\mathbf z}]=E[{\mathbf x}]+E[{\mathbf y}] $

# %% [markdown]
# ### Solution
#
# $E[{\mathbf x}]=-1*0.1+0.1=0$
#
# $E[{\mathbf y}]=0.1+1.6+0.3=2$
#
# <div align="center">
#
# |   x   |   y   | z = x + y |   P    |
# |:-----:|:-----:|:----------:|:------:|
# |  -1   |   1   |     0      |  0.01  |
# |  -1   |   2   |     1      |  0.08  |
# |  -1   |   3   |     2      |  0.01  |
# |   0   |   1   |     1      |  0.08  |
# |   0   |   2   |     2      |  0.64  |
# |   0   |   3   |     3      |  0.08  |
# |   1   |   1   |     2      |  0.01  |
# |   1   |   2   |     3      |  0.08  |
# |   1   |   3   |     4      |  0.01  |
#
# </div>
#
#
#
# The domain of $\mathbf z $  is:
# $$
# {0, 1, 2, 3, 4}
# $$
# and the probability function takes the values
# $$P={0.01, 0.16,0.66,0.16,0.01}$$
#
# $E[\mathbf z ]=0.16+0.66*2+0.16*3+0.01*4=2=E[{\mathbf x}]+ E[{\mathbf y}]$

# %% [markdown]
# ## PROBA.QA.2
# Let $ {\mathbf y}=3 {\mathbf x} $ and $ {\mathbf x} \sim N(0,1) $.
#
# What is the covariance of $ {\mathbf y} $  and $ {\mathbf x} $ ?

# %% [markdown]
# ### Solution
# Since
# $\mu_x=E[\mathbf x]=0, \text{Var}[\mathbf x]=1, \mu_y= E[\mathbf y]=3E[\mathbf x]=0$, we have
#
#  $$
#  \text{Cov}({\mathbf x},{\mathbf y})=E[ ({\mathbf x}-\mu_x) ({\mathbf y}-\mu_y))] =E[ 3 ({\mathbf x}^2)]=3
#  $$

# %% [markdown]
# ## PROBA.QA.3
# Let us consider three binary random variables  $ {\mathbf x}_1,   {\mathbf x}_2,  {\mathbf x}_3 $
# and their joint distribution
# How many parameters have to be set to define their joint distribution if
#
# 1. we have no additional information
# 2. the three variables are independent
# 3.  $ {\mathbf x}_1 $ is conditionally independent of $ {\mathbf x}_3 $ given $ {\mathbf x}_2 $
# 4. $ {\mathbf x}_1 $ is independent of the other two variables
#
# Hint: use the chain rule

# %% [markdown]
# ### Solution
#
# 1. 8-1=7 parameters have to be defined since the sample space is made of 8 experimental outcomes, and the probabilistic constraint applies.
# 2. 1*3=3 since $P(\mathbf x_1, \mathbf x_2, \mathbf x_3)=P(\mathbf x_1)P(\mathbf x_2)P(\mathbf x_3)$, and for each of the three terms, one parameter is sufficient.
# 3. 2+2+1=5 By using the chain rule and the conditional independence, we obtain $P(\mathbf x_1,\mathbf x_2,\mathbf x_3)=P(\mathbf x_1| \mathbf x_2,\mathbf x_3)P(\mathbf x_2| \mathbf x_3) P(\mathbf x_3) = P(\mathbf x_1| \mathbf x_2)P(\mathbf x_2| \mathbf x_3) P(\mathbf x_3) $
# 4. 1+2+1=4 By using the chain rule and the conditional independence, we obtain $P(\mathbf x_1,\mathbf x_2,\mathbf x_3)=P(\mathbf x_1| \mathbf x_2,\mathbf x_3)P(\mathbf x_2| \mathbf x_3) P(\mathbf x_3) = P(\mathbf x_1)P(\mathbf x_2| \mathbf x_3) P(\mathbf x_3) $

# %% [markdown]
# ## PROBA.QA.4
#
# Let $ {\mathbf x} $ a random binary variable taking values 0 and 1.
# What is the probability $ P( {\mathbf x}=0| {\mathbf x}=1) $?

# %% [markdown]
# ### Solution
# Intersection of the two events $ {\mathbf x}=1 $ and $ {\mathbf x}=0 $ is null then the probability is 0.

# %% [markdown]
# ## PROBA.QA.5
#
# Let $ {\mathbf x} $ and $ {\mathbf  y} $  two discrete r.v.s.
# The domain of $ {\mathbf x} $ is   $\{-1,0,1\} $ and its probability distribution is uniform (i.e. 1/3 for all values).
#
# Let $ {\mathbf  y} = {\mathbf x}^2 $
#
#  * Compute  $E[\mathbf x \mathbf y ]$
#
#  * Show that the two variables are uncorrelated yet dependent.

# %% [markdown]
# ### Solution
#
# While ${\mathbf x}$  takes three values, ${\mathbf y}$ may take only two values: 0 and 1.
# Also
# $E[\mathbf x]= 0$
#
# The variable ${\mathbf z}={\mathbf x} {\mathbf y}$ may then take three  values:
# $$-1, 0, 1$$
#
# Let us compute the probability of the three possible values
#
# * $P({\mathbf z}=-1)= P({\mathbf x}=-1,{\mathbf y}=1)=P({\mathbf y}=1| \mathbf{x}=-1) P({\mathbf x}=-1)=1*1/3$
# * $P({\mathbf z}=0)= P({\mathbf x}=1,{\mathbf y}=0)+P(\mathbf x=-1,{\mathbf y}=0)+P({\mathbf x}=0,{\mathbf y}=0)=0+0+1/3$
# * $P(\mathbf{z}=1)=P({\mathbf x}=1,{\mathbf y}=1)=1/3$
#
#
# Then $E[\mathbf{z}]=E[\mathbf x \mathbf y] = -1/3+0+1/3=0 = E[\mathbf x]E[\mathbf y] $
#
# The two variables are then uncorrelated but dependent
#
# $ P({\mathbf y}=0) =P({\mathbf x}=0)=1/3 \neq  P(\mathbf y =0| \mathbf x=0 )=1 $

# %% [markdown]
# ## PROBA.QA.6
# ![Screenshot 2025-02-14 at 12.29.14.png](attachment:7e38cc4b-507f-46f4-b067-b2fd23b008a9.png)

# %% [markdown]
# ### Solution
#
# * b: They have the same expectation.
# * h: They have the same probability of taking a value bigger than zero.
# * i :Their difference is not necessarily zero
# * j: They have the same probability of taking a value smaller than zero.
#
# Why not?
# * a., c., e., g. : no statement about dependence and taking identical values.
# * d. e.g. if  $\mathbf x \sim U[-1,1]$ and $\mathbf y= - \mathbf x$, $\mathbf x + \mathbf y=0$

# %% [markdown]
# ## PROBA.QA.7
# Let $ {\mathbf x} $ be a random variable taking the values -1, 0 and 1 with probabilities 1/3,1/3,1/3 respectively and
# let $$ {\mathbf y}={\mathbf x}^2 $$
# What is the probability $ P( {\mathbf x}=1| {\mathbf y}=1) $ ?
#
# Test the result in Python by using Monte Carlo.

# %% [markdown]
# ### Solution
# By using Bayes' theorem
#
#  $$ P( {\mathbf x}=1| {\mathbf y}=1) = \frac{P( {\mathbf y}=1| {\mathbf x}=1)P( {\mathbf x}=1) }{P( {\mathbf y}=1| {\mathbf x}=1)P( {\mathbf x}=1) +P( {\mathbf y}=1| {\mathbf x}=0)P( {\mathbf x}=0)+ P( {\mathbf y}=1| {\mathbf x}=-1)P( {\mathbf x}=-1) }=  \frac{1*1/3}{2/3}=1/2 $$

# %%
import numpy as np
R = 50000

X = np.random.choice([-1, 0, 1], size=R, replace=True)
Y = X**2

I = np.where(Y == 1)[0]
print(np.sum(X[I] == 1) / len(I))
# Out:
# 0.5009150091500915

# %% [markdown]
# ## PROBA.QA.8
# Let  $ {\mathbf y} $ and $ {\mathbf x} $  be two  random variables that can take three values.
#
# If $ {\mathbf x} $  and $ {\mathbf y} $  are dependent , is  $P({\mathbf y}=1| {\mathbf x} =1 ) $ always different  from $P({\mathbf y}=1 )$ ?

# %% [markdown]
# ### Solution
# Not necessarily. It could be that  $$P({\mathbf y}=1| {\mathbf x} =1 ) = P({\mathbf y}=1 ) $$  but
# $$P({\mathbf y}=1| {\mathbf x} =0 ) \neq P({\mathbf y}=1 ) $$
#
# In the case of binary variables this is not true

# %% [markdown]
# ## PROB.QA.9
#
# Let  $ {\mathbf y} $ and $ {\mathbf x}$  be two binary random variables. Whatever the joint distribution, it is always true that $P( {\mathbf x} =1 | {\mathbf y} =1) + P( {\mathbf x} =1 | {\mathbf y} =0)=1  $?

# %% [markdown]
# ### Solution
# No. Take a look at the properties of conditional distribution: $P(e | \cdot)$ with a fixed term at the left of the conditional bar is NOT a  probability distribution.
#
# The probability of $\mathbf x=1$ given two different events does not have to respect any constraint. For instance
# if $\mathbf x$ and $\mathbf y$ are independent,
# $$
# P( {\mathbf x} =1 | {\mathbf y} =1) + P( {\mathbf x} =1 | {\mathbf y} =0)=2 P( {\mathbf x})
# $$

# %% [markdown]
# ## PROBA.QA.10
# Let  $ {\mathbf y}$ and $ {\mathbf x} $  be two binary independent random variables
# taking values in $\{0,1\}$ with  $P( {\mathbf x} =1 )= P( {\mathbf y} =1)=1/2  $.
#
# 1. Compute the probability that both variables are equal to one, given that at least one is equal to one.
# 2.  Compute the probability that  $ 𝐱=1 $
# given that at least one of the two r.v.s takes a value equal to one.
# 3. Test the two results by using Python and Monte Carlo

# %% [markdown]
# ### Solution
#
# #### 1
# By Bayes' theorem
#
#   $$P( {\mathbf x} =1 \land {\mathbf y} =1 |  {\mathbf x} =1 \lor {\mathbf y} =1) = \frac{P( {\mathbf x} =1 \lor {\mathbf y} =1 |  {\mathbf x} =1 \land {\mathbf y} =1) P(   {\mathbf x} =1 \land {\mathbf y} =1) }{P( {\mathbf x} =1 \lor {\mathbf y} =1)} $$
# Since
# $ P( {\mathbf x} =1 \lor {\mathbf y} =1 |  {\mathbf x} =1 \land {\mathbf y} =1) =1 $
#
# and
#
#
#   $$
#   P( {\mathbf x} =1 \lor {\mathbf y} =1)=\\
#   =P( {\mathbf x} =1 \lor {\mathbf y} =1 | {\mathbf x} =1 \land {\mathbf y} =1) P ({\mathbf x} =1 \land {\mathbf y} =1) +  P( {\mathbf x} =1 \lor {\mathbf y} =1 | {\mathbf x} =1 \land {\mathbf y} =0) P ({\mathbf x} =1 \land {\mathbf y} =0)+\\ P( {\mathbf x} =1 \lor {\mathbf y} =1 | {\mathbf x} =0 \land {\mathbf y} =1) P ({\mathbf x} =0 \land {\mathbf y} =1)+\\  P( {\mathbf x} =1 \lor {\mathbf y} =1 | {\mathbf x} =0 \land {\mathbf y} =0) P ({\mathbf x} =0 \land {\mathbf y} =0)= \\=1*1/4+1*1/4+1*1/4+0 =3/4
#
#   $$
#
# we have that
#
#  $$ P( {\mathbf x} =1 \land {\mathbf y} =1 |  {\mathbf x} =1 \lor {\mathbf y} =1) =(1*1/4)/(3/4)=1/3 $$
#
# #### 2
#
# By Bayes' theorem
#
# $ 𝑃(\mathbf 𝐱=1|𝐱=1 \lor  \mathbf 𝐲=1)=
# 𝑃(\mathbf 𝐱=1 \lor  \mathbf 𝐲=1| \mathbf 𝐱=1)𝑃(\mathbf 𝐱=1) / 𝑃(\mathbf 𝐱=1 \lor \mathbf𝐲=1) $
#
# Since
# $ 𝑃(\mathbf 𝐱=1 \lor \mathbf 𝐲=1|\mathbf 𝐱=1)=1 $
# and
# $𝑃(\mathbf 𝐱=1)=1/2$
#
# and
#
# $
# 𝑃(\mathbf 𝐱=1 ∨ \mathbf 𝐲=1)=3/4
# $
#
# we have that
# $$ 𝑃(\mathbf 𝐱=1|\mathbf 𝐱=1∨ \mathbf 𝐲=1)=1/2∗4/3=2/3 $$

# %%
import numpy as np

R = 100000

X = np.random.choice([0, 1], size=R)  
Y = np.random.choice([0, 1], size=R)  

I = np.where((X == 1) | (Y == 1))[0]  
prob1 = np.sum((X[I] == 1) & (Y[I] == 1)) / len(I)  #

print(prob1)

prob2 = np.sum(X[I] == 1) / len(I)  #

print(prob2)
# Out:
# 0.33169641074779416
# 0.6661343341185239

# %% [markdown]
# ## PROBA.QA.11
#
# Let us consider three r.v.s $\mathbf x, \mathbf y,\mathbf z$.
#
# 1. Prove that
#
# $$
# \text{Cov}[\mathbf x+ \mathbf y , \mathbf z] = \text{Cov}[\mathbf x , \mathbf z]+
# \text{Cov}[\mathbf y , \mathbf z]
# $$
#
# 2. Test the result in Python by using Monte Carlo and supposing that $\mathbf x \sim U(-2,2)$ and $\mathbf y,\mathbf z$ are standard normal.

# %% [markdown]
# ### Solution
# $$
# \text{Cov}[\mathbf x+ \mathbf y,\mathbf z]=E[\mathbf z(\mathbf x+\mathbf y)]-E[\mathbf x+\mathbf y]*E[\mathbf z]=E[\mathbf z \mathbf x]+E[\mathbf z \mathbf y]-E[\mathbf x]E[\mathbf z]-E[\mathbf y]E[\mathbf z]=\text{Cov}[\mathbf z, \mathbf x]+\text{Cov}[\mathbf y, \mathbf z]
# $$

# %%
import numpy as np

N = 1000

x = np.random.uniform(-2.0, 2.0, size=N)
y = np.random.normal(loc=0.0, scale=1.0, size=N)
z = np.random.normal(loc=0.0, scale=1.0, size=N)

# Calculate covariance between (x+y) and z, extracting the off-diagonal element from the covariance matrix.
cov_xy_z = np.cov(x + y, z)[0, 1]
# Calculate covariance between x and z.
cov_x_z = np.cov(x, z)[0, 1]
# Calculate covariance between y and z.
cov_y_z = np.cov(y, z)[0, 1]

print(cov_xy_z, ":", cov_x_z + cov_y_z)
# Out:
# 0.009580348257408175 : 0.009580348257408104

# %% [markdown]
# ## PROBA.Q.12
# Let $\mathbf x$ and $\mathbf y$ two independent standard random variables.
#
# Let $\mathbf z=\mathbf x$ and $\mathbf w=\rho \mathbf x +\sqrt{1-\rho^2}\, \mathbf y$ with $-1 \le \rho \le 1$
#
# 1. Compute the correlation between $\mathbf z$ and $\mathbf w$.
# 2. Test the result in Python

# %% [markdown]
# ### Solution
# Since $\text{Var}[\mathbf y]=\text{Var}[\mathbf x]=\text{Var}[\mathbf z]=1$, we have
# $\text{Var}[\mathbf w]=\rho^2+1-\rho^2=1$ and $\text{Cor}[\mathbf z,\mathbf w]=\text{Cov}[\mathbf z,\mathbf w]$
#
# Since
# * $E[\mathbf x]=E[\mathbf w]=0$
# * $ E[\mathbf x^2]=\text{Var}[\mathbf x] - E[\mathbf x]^2= 1$
# * $ E[\mathbf  x \mathbf y]=0$ ($\mathbf  x$ and $\mathbf  y$ are independent) we have
#
# $$\text{Cor}[\mathbf z, \mathbf w]=\text{Cov}[\mathbf z,\mathbf w]=
# E[\mathbf z \mathbf w]=E[\rho \mathbf x^2+\sqrt{1-\rho^2} \, \mathbf x \mathbf y]=\rho E[ \mathbf x^2]= \rho$$

# %%
import numpy as np
N = 100000
for rho in np.arange(-1, 1.1, 0.2):
    X = np.random.normal(size=N)
    Y = np.random.normal(size=N)
    Z = X
    W = rho * X + np.sqrt(1 - rho**2) * Y
    print(np.round(rho,2), ":", np.round(np.corrcoef(Z, W)[0, 1],2))
# Out:
# -1.0 : -1.0
# -0.8 : -0.8
# -0.6 : -0.6
# -0.4 : -0.4
# -0.2 : -0.2
# -0.0 : 0.0
# 0.2 : 0.2
# 0.4 : 0.4
# 0.6 : 0.6
# 0.8 : 0.8
# 1.0 : 1.0
